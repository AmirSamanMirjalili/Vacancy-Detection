# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirSamanMirjalili/Vacancy-Detection/blob/main/Vacancy_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import data set

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="auvHY15qNa57ejag08X1")
project = rf.workspace("test3-jl78w").project("free-space-2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.

# %% [markdown]
# # install yolo-V8

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd ultralytics
# !pip install -r requirements.txt
# !pip install ultralytics
# !pip install Ipython
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 23064, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 23064 (delta 40), reused 73 (delta 30), pack-reused 22968
# Receiving objects: 100% (23064/23064), 13.70 MiB | 14.27 MiB/s, done.
# Resolving deltas: 100% (16130/16130), done.
# /content/ultralytics
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 40.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 33.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 49.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Train yolo

# %%
# !yolo task=detect mode=train model=yolov8n.pt data='/content/ultralytics/free-space-2-1/data.yaml' epochs=35 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 116MB/s]
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
